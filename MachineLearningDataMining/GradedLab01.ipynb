# %% [markdown]
# # Machine Learning and Data Mining: Graded Lab 01
# ---------------

# %% [markdown]
# #### Grading
# For this graded lab you can get a total of 15 points. These 15 points count 10% of your final grade for the course.
#
# #### Deadline
# You have 20 days to finish the lab. You must submit the graded lab the evening before the lab-session.
#
# - **If you have lab on Friday: Hand-in on 11.11.21, 11.59 p.m.**
# - **If you have lab on Saturday: Hand-in on 12.11.21, 11.59 p.m.**
#
# #### Submission
# You have to solve the labs in groups of **two** students. If the class has an uneven number of students, there can be one group of three students. For this group, however, task 3 is graded more strictly and extra effort is expected.
#
# Submit your GradedLab01.pynb file renamed to **LastnameStudent01_LastnameStudent02.ipynb** in moodle.
# Please submit a runnable python notebook file **and** an exported HTML with all cells executed (the results must be visible in the HTML).
# All other submissions will be rejected and graded with 0 points.
#
# #### Presentation Exercise 3
# The students are completely free to decide how to solve exercise 3. If the exercise is not solved in this notebook, a detailed description with screenshots must be included. In any case, task 3 must be presented to the lecturer during class. Thereby, a live demonstration is expected and not a presentation with PowerPoint. This demonstration should take about 5 minutes.

# %%
#Wichtiges:
#-lauffähiges Python notebook und mit exportierter HTMLversion -> Sonst Note1
#-Projektdatei muss so heissen: PioLogin01_Arslan02.ipynb
#-Aufgabe3 muss präsentiert werden, ca. 5min live oder über MS-Team. Kein Powerpoint.

# %% [markdown]
# ---
#
# ## Exercise 1: Implement a content-based recommender for the data in the movies.csv file [4 points].
# The movies.csv file contains a dataset extracted from IMDB with several attributes. For example, the title, plot, and the language of the movies.

# %% [markdown]
# ##### __(a) The user Calvin hasn't watched any movies yet. Print the top 5 movies based on the rating attribute, as recommendations for him [0.5 points].__

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('movies.csv')
pd.set_option('max_colwidth', None)
df

# %%
dfSortedByRating = df.sort_values(by=['rating'])
dfTop = dfSortedByRating.tail(5)
dfTop

# %% [markdown]
# ##### __(b) The user Calvin hasn't still watched any movies yet. We  just know that he likes english speaking movies. Print the top 5 movies based on the rating attribute, which have only the language "English" in the languages attribute, as recommendations for him [0.5 points].__

# %%
dfFiltered = df[df['languages'] == '[\'English\']']
dfFiltered

# %%
dfSorted = dfFiltered.sort_values(by=['rating'])
dfTopEnglish = dfSorted.tail(5)
dfTopEnglish

# %% [markdown]
# ##### __(c) Still Calvin hasn't still watched any movies yet. However, we noticed that he took more time on the recommendations with the genres "Drama" and "Crime", therefore we assume that he is interested in this genre combination. Print the top 3 movies based on the rating attribute, which have at least the genres "Drama" and "Crime" as recommendations for him [0.5 points].__

# %%
dfSortedCrimeDrama = df[(df['languages'] == '[\'English\']') & (df['genres'].str.contains('Drama' or 'Crime'))]
dfSortedCrimeDrama

# %%
dfSortedCD = dfSortedCrimeDrama.sort_values(by=['rating'], ascending=False)
dfTopCD = dfSortedCD.head(3)
dfTopCD

# %% [markdown]
# ##### __(d) Now, Calvin has watched the movie with the ID 110912. Print the top 3 movies based on the rating attribute, which have the same director as the watched movie with the ID 110912 as recommendations for him. The already watched movie should not be within the recommendations [0.5 points].__

# %%
GetMovie = df[df['id'] == 110912]
GetMovie
## What are the rating attributes? just the rating or also the languages and genres?

# %%
getSortedDirectorGenre = df[df['director'] == 'Quentin Tarantino']
getSortedDirectorGenre

# %%
dfWithoutPF = getSortedDirectorGenre.drop(29)
dfWithoutPF

# %%
dfFinal = dfWithoutPF.sort_values(by=['rating'], ascending=False)
dfFinal

# %%
dfTop3 = dfFinal.head(3)
dfTop3

# %% [markdown]
# ##### __(d) Now, Calvin has watched the movie with the ID 1502397 and we want to recommend movies with a similar plot. Remove all stopwords from the plot attribute and split the content of the plot attribute into terms. Then calculate the term similarity between the plot of the watched movie and all others. Use data pre-processing methods wherever needed. Print the top 3 movies based on the calculated term similarity and the rating of the movie.  [2 points].__

# %%
Movie = df[df['id'] == 1502397]
Movie

# %%
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
all_stopwords = stopwords.words('english') 
stopWord_list = [',', '(', ')', '1', '2', '3', '4', '5', '6', '7', '8', '9', '0', '.']
all_stopwords.extend(stopWord_list)


def getPlotWithoutStopwords(index):
    selectedMovie = df[df['id'] == index]
    Text = selectedMovie['plot'].to_string()
    textWithoutNum = re.sub(r'\d+', '', Text)
    text_tokens = word_tokenize(textWithoutNum)
    tokens_without_sw = [word for word in text_tokens if not word in all_stopwords]
    return tokens_without_sw

referenceTokens = getPlotWithoutStopwords(1502397)
print(referenceTokens)

# %%
distlist = []
for idx in df.index:
    tokens = getPlotWithoutStopwords(int(df.loc[idx, 'id']))
    distlist.append(nltk.edit_distance(''.join(tokens), ''.join(referenceTokens)))
df["LevenDistance"] = distlist
df

# %%
dfSorted = df.sort_values(by=['LevenDistance'], ascending=False)
dfFinal = dfSorted.tail(3)
dfFinal

# %% [markdown]
# ---
#
# ## Exercise 2: Implement Collaborative Filtering Recommenders for the data in the ratings.csv file [6 points].
# ##### __The ratings.csv file contains a dataset extracted from IMDB with ratings for movies from several users. Implement a user-based and an item-based collaborative filtering recommender. Use data pre-processing methods wherever needed. Print the top 3 recommended movies for each user in the dataset for the user-based and the item-based version. Don't recommend any movies the user has already watched.__

# %% [markdown]
# Setup Code

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_csv('ratings.csv')
dm = pd.read_csv('movies.csv')
pd.set_option('max_colwidth', None)
df
# Out:
#            id      user  rating
# 0     2897196  Margaret     3.0
# 1     1329338  Margaret     3.0
# 2     7065882  Margaret     2.0
# 3     1615477  Margaret     5.0
# 4     2316564  Margaret     5.0
# ...       ...       ...     ...
# 3650   559276   Bridget     3.0
# 3651  3295276   Bridget     4.0
# 3652  4138326   Bridget     4.0
# 3653   660187   Bridget     3.0
# 3654  1634540   Bridget     5.0
#
# [3655 rows x 3 columns]

# %% [markdown]
#     We first tried to generate the matrix of simulatiries manually but our code was really inefficient
#     calculation the entire matrix took way too long so we decided to generate the user_similarity matrix
#     using a pivot table and the sklearn library
#
#     https://stackoverflow.com/questions/45387476/cosine-similarity-between-each-row-in-a-dataframe-in-python
#
#     print(generateManual())

# %%
#users = ["not implemented"]
#
#
#def getUsers():
#    users = df["user"].drop_duplicates().tolist()
#    return users
#
#
#def getUserReview(user):
#    # gahn dure und hole alli ratings wo user = user
#    reviews = []
#    for idx in df.index:
#        if df.loc[idx, "user"] == user:
#            reviews.append(df.loc[idx])
#
#    return pd.DataFrame(reviews, columns=["id", "user", "rating"])
#
#
#def getMovieReview(movieID):
#    # gahn dure und hole alli ratings wo Movie = Movie
#    reviews = []
#    for idx in df.index:
#        if df.loc[idx, "id"] == movieID:
#            reviews.append(df.loc[idx])
#    return pd.DataFrame(reviews, columns=["id", "user", "rating"])
#
#
#def findAB(userA, userB):
#    sameReviewedMovies = []
#    reviewlistA = getUserReview(userA)
#    reviewlistB = getUserReview(userB)
#    for idxOfA in reviewlistA.index:
#        for idxOfB in reviewlistB.index:
#            if reviewlistA.loc[idxOfA, "id"] == reviewlistB.loc[idxOfB, "id"]:
#                sameReviewedMovies.append(reviewlistA.loc[idxOfA, "id"])
#    return sameReviewedMovies
#
#
#def similarity(userA, userB):
#    same = findAB(userA, userB)
#    ratingA = []
#    # collet ratings of A
#    for id in same:
#        rating = df[(df["id"] == id) & (df["user"] == userA)]
#        ratingA.append(rating["rating"].tolist()[0])
#
#    ratingB = []
#    # collet ratings of A
#    for id in same:
#        rating = df[(df["id"] == id) & (df["user"] == userB)]
#        ratingB.append(rating["rating"].tolist()[0])
#
#    upperTerm = 0
#    for i in range(len(ratingA)):
#        upperTerm += ratingA[i] * ratingB[i]
#
#    lowerTerm1 = 0
#    allRatingsA = getUserReview(userA)["rating"].tolist()
#    for i in range(len(allRatingsA)):
#        lowerTerm1 += allRatingsA[i] ** 2
#
#    lowerTerm2 = 0
#    allRatingsB = getUserReview(userB)["rating"].tolist()
#    for i in range(len(allRatingsB)):
#        lowerTerm2 += allRatingsB[i] ** 2
#
#    lowerTerm = np.sqrt(lowerTerm1 * lowerTerm2)
#
#    similarity = upperTerm / lowerTerm
#
#    return similarity
#
#
#def applySimilarity(row):
#    for idx in row.index:
#        row.loc[idx] = similarity(row.name, idx)
#    return row
#
#
#def generateManual():
#    ratings = df.pivot_table(index="user", columns="id", values="rating", fill_value=0)
#    user_similarity = pd.DataFrame(1, columns=ratings.index.values, index=ratings.index)
#    user_similarity.apply(applySimilarity, axis=1)
#    return user_similarity
#

# %% [markdown]
# # Real Exercise Code

# %% [markdown]
# ## User Based Recommendations

# %%
users = df["user"].drop_duplicates().tolist()

ratings = df.pivot_table(
    index="user", columns="id", values="rating", fill_value=0
)  # Tabelle generieren mit User und Movie ID und deren Ratings

"""
In diesem Abschnitt werden die Ratings berechnet, dafür haben wir die vordefinierte Funktion cosine_similarity() verwendet von
from sklearn.metrics.pairwise import cosine_similarity
Damit man cosinus_similarity verwenden kann, braucht man eine Matrix mit allen Ratings, die wir der Methode mitgeben.

"""

userSimilarityMatrix = pd.DataFrame(
    cosine_similarity(ratings), columns=ratings.index.values, index=ratings.index
)

movies = dm.set_index("id")  # Movies indexieren

# Get all ratings of movies that the "user" did not saw
def getUnseenRatings(ratings, user):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    all_movies = ratings.columns.values
    unseen_movies = np.setdiff1d(all_movies, seen_movies)
    return ratings.loc[getSimilarUsers(user).index, unseen_movies]


# Multiply rating of unseen movies with simularity score of simlar users according to slide 23 of MLDM_05_RecommenderSystems_mony.pdf
# Then devide the sum by
def getRecommendationsOfRatings(ratings, user):
    unseenRatings = getUnseenRatings(ratings, user)
    sumOfRating = unseenRatings.mul(getSimilarUsers(user), axis=0).sum()
    sumOfUserSimilarity = getSimilarUsers(user).sum()
    return sumOfRating / sumOfUserSimilarity


# Sort all users expet the "user" according the the similary to the "user"
def getSimilarUsers(user):
    return userSimilarityMatrix.loc[user].sort_values(ascending=False).drop(user)


def getUserBasedRecommendationsFor(user):
    # Get all recommendations
    recommendations = getRecommendationsOfRatings(ratings, user)
    # Get the top 3 movies
    recommendations = recommendations.sort_values(ascending=False).head(3)

    return recommendations


for user in users:
    print(
        "The user-based recommendations for "
        + user
        + " are: "
        + str(getUserBasedRecommendationsFor(user))
    )
# Out:
# The user-based recommendations for Margaret are: id
# 71562     0.464353
# 468569    0.338396
# dtype: float64
# The user-based recommendations for Mandy are: id
# 105236    2.096967
# 110912    2.035740
# 116367    1.868331
# dtype: float64
# The user-based recommendations for Carolyn are: id
# 105236    2.100431
# 110912    2.039484
# 116367    1.871562
# dtype: float64
# The user-based recommendations for Stephen are: id
# 119396    0.993878
# 111161    0.832591
# 68646     0.822226
# dtype: float64
# The user-based recommendations for Mario are: id
# 105236    2.107012
# 110912    2.049242
# 116367    1.879106
# dtype: float64
# The user-based recommendations for Addie are: id
# 105236     2.136732
# 116367     1.917372
# 1028528    1.496403
# dtype: float64
# The user-based recommendations for Carl are: id
# 105236     2.140025
# 116367     1.918208
# 1028528    1.490948
# dtype: float64
# The user-based recommendations for Reid are: id
# 361748    1.170984
# 119396    0.950689
# 111161    0.792346
# dtype: float64
# The user-based recommendations for Clara are: id
# 105236    2.095662
# 110912    2.046139
# 116367    1.867334
# dtype: float64
# The user-based recommendations for Carmen are: id
# 116367     1.934715
# 1028528    1.491928
# 3460252    1.328770
# dtype: float64
# The user-based recommendations for Ruth are: id
# 105236     2.097911
# 116367     1.882132
# 1028528    1.466985
# dtype: float64
# The user-based recommendations for Daniel are: id
# 3295276    2.857554
# 4138326    2.759875
# 660187     2.567353
# dtype: float64
# The user-based recommendations for Robert are: id
# 71562     0.432875
# 468569    0.297515
# dtype: float64
# The user-based recommendations for Jacquelyn are: id
# 660187     2.590952
# 1634540    2.268498
# 105236     2.080068
# dtype: float64
# The user-based recommendations for Kendra are: id
# 468569    0.301906
# dtype: float64
# The user-based recommendations for Amanda are: id
# 119396    0.965245
# 111161    0.809612
# 68646     0.798926
# dtype: float64
# The user-based recommendations for Jack are: id
# 105236     2.120880
# 116367     1.920206
# 1028528    1.492704
# dtype: float64
# The user-based recommendations for Flora are: id
# 468569    0.30354
# dtype: float64
# The user-based recommendations for Sandra are: id
# 111161    0.802116
# 68646     0.796106
# 71562     0.409241
# dtype: float64
# The user-based recommendations for Richard are: id
# 68646     0.823099
# 71562     0.429748
# 468569    0.295464
# dtype: float64
# The user-based recommendations for Rita are: id
# 119396    0.949865
# 111161    0.792293
# 68646     0.779234
# dtype: float64
# The user-based recommendations for Sarah are: Series([], dtype: float64)
# The user-based recommendations for Coy are: id
# 361748    1.166616
# 119396    0.956083
# 111161    0.796964
# dtype: float64
# The user-based recommendations for Gary are: id
# 3460252    1.380862
# 361748     1.148898
# 119396     0.930052
# dtype: float64
# The user-based recommendations for Tracy are: id
# 119396    0.960887
# 111161    0.801416
# 68646     0.791515
# dtype: float64
# The user-based recommendations for Joshua are: id
# 68646     0.836617
# 71562     0.433059
# 468569    0.298209
# dtype: float64
# The user-based recommendations for Thomas are: id
# 1028528    1.501864
# 3460252    1.326113
# 361748     1.117127
# dtype: float64
# The user-based recommendations for Jerry are: id
# 105236    2.101929
# 110912    2.042252
# 116367    1.871030
# dtype: float64
# The user-based recommendations for Steven are: Series([], dtype: float64)
# The user-based recommendations for Mark are: id
# 119396    0.985451
# 111161    0.818749
# 68646     0.809117
# dtype: float64
# The user-based recommendations for David are: id
# 660187     2.580046
# 1634540    2.253767
# 105236     2.070266
# dtype: float64
# The user-based recommendations for Della are: id
# 3295276    2.850449
# 4138326    2.761602
# 660187     2.575841
# dtype: float64
# The user-based recommendations for Maricela are: id
# 1028528    1.533898
# 3460252    1.360145
# 361748     1.132802
# dtype: float64
# The user-based recommendations for Barbara are: id
# 361748    1.149969
# 119396    0.943775
# 111161    0.788915
# dtype: float64
# The user-based recommendations for Julie are: id
# 71562     0.429982
# 468569    0.297187
# dtype: float64
# The user-based recommendations for Louise are: id
# 116367     1.908575
# 1028528    1.487104
# 3460252    1.317263
# dtype: float64
# The user-based recommendations for Ruby are: id
# 119396    0.951462
# 111161    0.797582
# 68646     0.786182
# dtype: float64
# The user-based recommendations for John are: id
# 116367     1.935274
# 1028528    1.500085
# 3460252    1.337753
# dtype: float64
# The user-based recommendations for William are: id
# 1028528    1.513784
# 3460252    1.341494
# 361748     1.132064
# dtype: float64
# The user-based recommendations for Matthew are: id
# 361748    1.152477
# 119396    0.941511
# 111161    0.782624
# dtype: float64
# The user-based recommendations for Charles are: id
# 111161    0.808383
# 68646     0.803628
# 71562     0.409679
# dtype: float64
# The user-based recommendations for Stacy are: id
# 1634540    2.278186
# 105236     2.080425
# 110912     2.045259
# dtype: float64
# The user-based recommendations for Iris are: id
# 660187     2.600368
# 1634540    2.269368
# 105236     2.075805
# dtype: float64
# The user-based recommendations for Millie are: id
# 468569    0.307876
# dtype: float64
# The user-based recommendations for Connie are: Series([], dtype: float64)
# The user-based recommendations for Tammie are: id
# 111161    0.801384
# 68646     0.787775
# 71562     0.407204
# dtype: float64
# The user-based recommendations for Ann are: id
# 1634540    2.255034
# 105236     2.067721
# 110912     2.028124
# dtype: float64
# The user-based recommendations for Jorge are: id
# 119396    0.940037
# 111161    0.784389
# 68646     0.771511
# dtype: float64
# The user-based recommendations for Leonard are: id
# 119396    0.966824
# 111161    0.801399
# 68646     0.794384
# dtype: float64
# The user-based recommendations for Lenna are: id
# 116367     1.945892
# 1028528    1.505557
# 3460252    1.330034
# dtype: float64
# The user-based recommendations for Josephine are: id
# 468569    0.292722
# dtype: float64
# The user-based recommendations for Jeremy are: id
# 1634540    2.271337
# 105236     2.080680
# 110912     2.022423
# dtype: float64
# The user-based recommendations for Sebastian are: id
# 1634540    2.270089
# 105236     2.083769
# 110912     2.031804
# dtype: float64
# The user-based recommendations for Rosalind are: id
# 660187     2.586759
# 1634540    2.257481
# 105236     2.080049
# dtype: float64
# The user-based recommendations for Sam are: id
# 105236    2.106031
# 110912    2.050089
# 116367    1.875325
# dtype: float64
# The user-based recommendations for Stacie are: id
# 119396    0.948428
# 111161    0.792147
# 68646     0.778218
# dtype: float64
# The user-based recommendations for Leigh are: id
# 1028528    1.502602
# 3460252    1.337070
# 361748     1.114389
# dtype: float64
# The user-based recommendations for Michael are: Series([], dtype: float64)
# The user-based recommendations for Ana are: id
# 116367     1.922263
# 1028528    1.493664
# 3460252    1.335928
# dtype: float64
# The user-based recommendations for Nathan are: id
# 361748    1.163376
# 119396    0.939862
# 111161    0.789136
# dtype: float64
# The user-based recommendations for Anthony are: id
# 3295276    2.847168
# 4138326    2.767174
# 660187     2.581236
# dtype: float64
# The user-based recommendations for Araceli are: id
# 116367     1.945244
# 1028528    1.507351
# 3460252    1.333901
# dtype: float64
# The user-based recommendations for Patricia are: id
# 4138326    2.764992
# 660187     2.581588
# 1634540    2.254988
# dtype: float64
# The user-based recommendations for Verna are: Series([], dtype: float64)
# The user-based recommendations for Julian are: id
# 105236     2.125811
# 116367     1.892708
# 1028528    1.475878
# dtype: float64
# The user-based recommendations for Suzanne are: id
# 361748    1.161447
# 119396    0.946627
# 111161    0.786755
# dtype: float64
# The user-based recommendations for Stacey are: id
# 105236     2.140703
# 116367     1.914479
# 1028528    1.496334
# dtype: float64
# The user-based recommendations for Aaron are: id
# 71562     0.443718
# 468569    0.301483
# dtype: float64
# The user-based recommendations for Antonio are: id
# 1028528    1.561554
# 3460252    1.384274
# 361748     1.160942
# dtype: float64
# The user-based recommendations for Mathew are: Series([], dtype: float64)
# The user-based recommendations for Allison are: id
# 4138326    2.747403
# 660187     2.573881
# 1634540    2.253139
# dtype: float64
# The user-based recommendations for Willie are: id
# 4138326    2.765929
# 660187     2.570618
# 1634540    2.242735
# dtype: float64
# The user-based recommendations for Adam are: id
# 468569    0.301154
# dtype: float64
# The user-based recommendations for Leslie are: Series([], dtype: float64)
# The user-based recommendations for Amy are: id
# 3460252    1.358164
# 361748     1.136484
# 119396     0.917663
# dtype: float64
# The user-based recommendations for Gladys are: Series([], dtype: float64)
# The user-based recommendations for Kathleen are: id
# 105236     2.117066
# 116367     1.900127
# 1028528    1.471762
# dtype: float64
# The user-based recommendations for Carlos are: id
# 468569    0.302263
# dtype: float64
# The user-based recommendations for Ron are: id
# 660187     2.603186
# 1634540    2.266696
# 105236     2.070875
# dtype: float64
# The user-based recommendations for Scott are: id
# 4138326    2.765706
# 660187     2.580099
# 1634540    2.250594
# dtype: float64
# The user-based recommendations for Eric are: id
# 468569    0.302456
# dtype: float64
# The user-based recommendations for Maryann are: id
# 660187     2.585203
# 1634540    2.251400
# 105236     2.071623
# dtype: float64
# The user-based recommendations for Howard are: id
# 111161    0.810385
# 68646     0.802316
# 71562     0.409656
# dtype: float64
# The user-based recommendations for Brian are: id
# 68646     0.791584
# 71562     0.408291
# 468569    0.279690
# dtype: float64
# The user-based recommendations for Marie are: id
# 68646     0.798042
# 71562     0.410013
# 468569    0.279759
# dtype: float64
# The user-based recommendations for Katharine are: id
# 1634540    2.269641
# 105236     2.089121
# 110912     2.047887
# dtype: float64
# The user-based recommendations for Blake are: id
# 3460252    1.377144
# 361748     1.153639
# 119396     0.943789
# dtype: float64
# The user-based recommendations for Carissa are: id
# 1028528    1.486636
# 3460252    1.317775
# 361748     1.105512
# dtype: float64
# The user-based recommendations for Ralph are: Series([], dtype: float64)
# The user-based recommendations for Max are: id
# 4138326    2.755874
# 660187     2.582854
# 1634540    2.245943
# dtype: float64
# The user-based recommendations for Clifford are: id
# 1634540    2.271436
# 105236     2.090744
# 110912     2.032376
# dtype: float64
# The user-based recommendations for George are: Series([], dtype: float64)
# The user-based recommendations for Henry are: id
# 1028528    1.534819
# 3460252    1.354157
# 361748     1.134756
# dtype: float64
# The user-based recommendations for Irene are: id
# 1028528    1.533492
# 3460252    1.370862
# 361748     1.139141
# dtype: float64
# The user-based recommendations for Sharon are: id
# 468569    0.302901
# dtype: float64
# The user-based recommendations for Jessica are: id
# 71562     0.429792
# 468569    0.293665
# dtype: float64
# The user-based recommendations for James are: id
# 361748    1.172558
# 119396    0.952962
# 111161    0.800548
# dtype: float64
# The user-based recommendations for Ronald are: id
# 71562     0.430449
# 468569    0.297123
# dtype: float64
# The user-based recommendations for Monica are: id
# 68646     0.811413
# 71562     0.415617
# 468569    0.287098
# dtype: float64
# The user-based recommendations for Craig are: id
# 105236    2.111542
# 110912    2.062452
# 116367    1.883689
# dtype: float64
# The user-based recommendations for Valorie are: id
# 1028528    1.503064
# 3460252    1.337883
# 361748     1.113129
# dtype: float64
# The user-based recommendations for Bob are: id
# 105236    2.117865
# 110912    2.069720
# 116367    1.885319
# dtype: float64
# The user-based recommendations for Esteban are: id
# 3295276    2.840408
# 4138326    2.767164
# 660187     2.569528
# dtype: float64
# The user-based recommendations for Ronny are: id
# 361748    1.151377
# 119396    0.938748
# 111161    0.781812
# dtype: float64
# The user-based recommendations for Frank are: Series([], dtype: float64)
# The user-based recommendations for Antonia are: id
# 71562     0.427863
# 468569    0.290499
# dtype: float64
# The user-based recommendations for Carol are: id
# 4138326    2.767769
# 660187     2.585743
# 1634540    2.258750
# dtype: float64
# The user-based recommendations for Evelyn are: id
# 1634540    2.256205
# 105236     2.078751
# 110912     2.034037
# dtype: float64
# The user-based recommendations for Sean are: id
# 119396    0.930730
# 111161    0.769710
# 68646     0.763368
# dtype: float64
# The user-based recommendations for Malcolm are: id
# 1634540    2.290745
# 105236     2.110278
# 110912     2.050065
# dtype: float64
# The user-based recommendations for Bridget are: id
# 105236    2.106149
# 110912    2.050463
# 116367    1.882523
# dtype: float64

# %% [markdown]
# ## Item Base Recommendations

# %%
users = df["user"].drop_duplicates().tolist()

ratings = df.pivot_table(
    index="user", columns="id", values="rating", fill_value=0
)  # Tabelle generieren mit User und Movie ID und deren Ratings

"""
In diesem Abschnitt werden die Ratings berechnet, dafür haben wir die vordefinierte Funktion cosine_similarity() verwendet von
from sklearn.metrics.pairwise import cosine_similarity
Damit man cosinus_similarity verwenden kann, braucht man eine Matrix mit allen Ratings, die wir der Methode mitgeben.

"""

movieSimilarityMatrix = pd.DataFrame(
    cosine_similarity(ratings.T), columns=ratings.T.index.values, index=ratings.T.index
)

movies = dm.set_index("id")  # Movies indexieren

# Multiply rating of unseen movies with simularity score of simlar users according to slide 23 of MLDM_05_RecommenderSystems_mony.pdf
# Then devide the sum by
def getRecommendationsOfRatings(ratings, user):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    similar_Movies = getSimilarMovies(user)
    sumOfMovies = similar_Movies.mul(ratings.T.loc[seen_movies, user]).sum(axis=1)
    sumOfMoviesSimilarity = similar_Movies.sum()
    return sumOfMovies / sumOfMoviesSimilarity


# Sort all users expet the "user" according the the similary to the "user"
def getSimilarMovies(user):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    all_movies = ratings.columns.values
    unseen_movies = np.setdiff1d(all_movies, seen_movies)
    return movieSimilarityMatrix[all_movies].drop(unseen_movies, axis=1).drop(seen_movies, axis=0)


def getUserBasedRecommendationsFor(user):
    # Get all recommendations
    recommendations = getRecommendationsOfRatings(ratings, user)
    # Get the top 3 movies
    recommendations = recommendations.sort_values(ascending=False).head(3)

    return recommendations


for user in users:
    print(
        "The item-based recommendations for "
        + user
        + " are: "
        + str(getUserBasedRecommendationsFor(user))
    )
# Out:
# The item-based recommendations for Margaret are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Mandy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carolyn are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Stephen are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Mario are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Addie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carl are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Reid are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Clara are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carmen are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ruth are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Daniel are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Robert are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jacquelyn are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Kendra are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Amanda are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jack are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Flora are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sandra are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Richard are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Rita are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sarah are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Coy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Gary are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Tracy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Joshua are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Thomas are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jerry are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Steven are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Mark are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for David are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Della are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Maricela are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Barbara are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Julie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Louise are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ruby are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for John are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for William are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Matthew are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Charles are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Stacy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Iris are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Millie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Connie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Tammie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ann are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jorge are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Leonard are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Lenna are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Josephine are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jeremy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sebastian are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Rosalind are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sam are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Stacie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Leigh are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Michael are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ana are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Nathan are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Anthony are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Araceli are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Patricia are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Verna are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Julian are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Suzanne are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Stacey are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Aaron are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Antonio are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Mathew are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Allison are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Willie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Adam are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Leslie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Amy are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Gladys are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Kathleen are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carlos are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ron are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Scott are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Eric are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Maryann are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Howard are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Brian are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Marie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Katharine are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Blake are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carissa are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ralph are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Max are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Clifford are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for George are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Henry are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Irene are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sharon are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Jessica are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for James are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ronald are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Monica are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Craig are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Valorie are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Bob are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Esteban are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Ronny are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Frank are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Antonia are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Carol are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Evelyn are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Sean are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Malcolm are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64
# The item-based recommendations for Bridget are: 68646    NaN
# 71562    NaN
# 104927   NaN
# dtype: float64

# %% [markdown]
# ## Brunner Version

# %%
users = df["user"].drop_duplicates().tolist()

ratings = df.pivot_table(
    index="user", columns="id", values="rating", fill_value=0
)  # Tabelle generieren mit User und Movie ID und deren Ratings

"""
In diesem Abschnitt werden die Ratings berechnet, dafür haben wir die vordefinierte Funktion cosine_similarity() verwendet von
from sklearn.metrics.pairwise import cosine_similarity
Damit man cosinus_similarity verwenden kann, braucht man eine Matrix mit allen Ratings, die wir der Methode mitgeben.

"""

movieSimilarityMatrix = pd.DataFrame(
    cosine_similarity(ratings.T), columns=ratings.T.index.values, index=ratings.T.index
)

movies = dm.set_index("id")  # Movies indexieren

def get_item_based_rec_for(user, fill_with_seen=True):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    all_movies = ratings.columns.values
    unseen_movies = np.setdiff1d(all_movies, seen_movies)
    simiMovies = movieSimilarityMatrix[all_movies].drop(unseen_movies, axis=1).drop(seen_movies, axis=0)
    recs = simiMovies.mul(ratings.T.loc[seen_movies, user]).sum(axis=1) / simiMovies.sum()
    recs = recs.sort_values(ascending=False).head(3)
    recs_len = len(recs)
    if recs_len < 3 and fill_with_seen:
        bestRatedMovies = ratings.loc[user].sort_values(ascending=False).head(3-recs_len)
        recs = recs.append(bestRatedMovies)
    ranking = movies.loc[recs.index]
    ranking["score"] = recs
    ranking = ranking.fillna(0)
    return ranking

for user in users:
    print(
        "The item-based recommendations for "
        + user
        + " are: "
        + str(get_item_based_rec_for(user))
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SELIMA~1\AppData\Local\Temp/ipykernel_10020/430100515.py in <module>
# ----> 1 users = df["user"].drop_duplicates().tolist()
#       2
#       3 ratings = df.pivot_table(
#       4     index="user", columns="id", values="rating", fill_value=0
#       5 )  # Tabelle generieren mit User und Movie ID und deren Ratings
#
# NameError: name 'df' is not defined

# %% [markdown]
# ---
#
# ## Exercise 3: Extend the Collaborative Filtering Recommender [5 points].
#
# You are free to choose which additional task you want to do. Ideas could be:
# - Implement your own UI for the Recommendation System.
# - Create a blogpost on the internet describing your approach and the system (Note: Do not just upload the notebook but create a text with references to the literature and appropriate plots).
# - Test alternative approaches to create recommendations and compare them.
# - **... your own idea ...**
#
# If you solve this task in this notebook, just describe your idea in a few sentences. If you do not solve it in the notebook, please provide a more detailed description and screenshots if appropriate.
#
# This exercise must be presented during the lab session. The task is graded based on innovation, effort, result, ...

# %% [markdown]
# ### Describe your idea here:
#
# .....

# %% [markdown]
# # Ideas
#
# - Optimize approach (might be difficult)
# - Verify Solution by using numbers from slides using fruits and doctors
# - Showing Learing steps about ineffictions (TODO SELIM ASK ABOUT IDEA)
