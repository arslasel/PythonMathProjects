# %% [markdown]
# # Machine Learning and Data Mining: Graded Lab 01
# ---------------

# %% [markdown]
# #### Grading
# For this graded lab you can get a total of 15 points. These 15 points count 10% of your final grade for the course.
#
# #### Deadline
# You have 20 days to finish the lab. You must submit the graded lab the evening before the lab-session.
#
# - **If you have lab on Friday: Hand-in on 11.11.21, 11.59 p.m.**
# - **If you have lab on Saturday: Hand-in on 12.11.21, 11.59 p.m.**
#
# #### Submission
# You have to solve the labs in groups of **two** students. If the class has an uneven number of students, there can be one group of three students. For this group, however, task 3 is graded more strictly and extra effort is expected.
#
# Submit your GradedLab01.pynb file renamed to **LastnameStudent01_LastnameStudent02.ipynb** in moodle.
# Please submit a runnable python notebook file **and** an exported HTML with all cells executed (the results must be visible in the HTML).
# All other submissions will be rejected and graded with 0 points.
#
# #### Presentation Exercise 3
# The students are completely free to decide how to solve exercise 3. If the exercise is not solved in this notebook, a detailed description with screenshots must be included. In any case, task 3 must be presented to the lecturer during class. Thereby, a live demonstration is expected and not a presentation with PowerPoint. This demonstration should take about 5 minutes.

# %%
#Wichtiges:
#-lauffähiges Python notebook und mit exportierter HTMLversion -> Sonst Note1
#-Projektdatei muss so heissen: PioLogin01_Arslan02.ipynb
#-Aufgabe3 muss präsentiert werden, ca. 5min live oder über MS-Team. Kein Powerpoint.

# %% [markdown]
# ---
#
# ## Exercise 1: Implement a content-based recommender for the data in the movies.csv file [4 points].
# The movies.csv file contains a dataset extracted from IMDB with several attributes. For example, the title, plot, and the language of the movies.

# %% [markdown]
# ##### __(a) The user Calvin hasn't watched any movies yet. Print the top 5 movies based on the rating attribute, as recommendations for him [0.5 points].__

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('movies.csv')
pd.set_option('max_colwidth', None)
df

# %%
dfSortedByRating = df.sort_values(by=['rating'])
dfTop = dfSortedByRating.tail(5)
dfTop

# %% [markdown]
# ##### __(b) The user Calvin hasn't still watched any movies yet. We  just know that he likes english speaking movies. Print the top 5 movies based on the rating attribute, which have only the language "English" in the languages attribute, as recommendations for him [0.5 points].__

# %%
dfFiltered = df[df['languages'] == '[\'English\']']
dfFiltered

# %%
dfSorted = dfFiltered.sort_values(by=['rating'])
dfTopEnglish = dfSorted.tail(5)
dfTopEnglish

# %% [markdown]
# ##### __(c) Still Calvin hasn't still watched any movies yet. However, we noticed that he took more time on the recommendations with the genres "Drama" and "Crime", therefore we assume that he is interested in this genre combination. Print the top 3 movies based on the rating attribute, which have at least the genres "Drama" and "Crime" as recommendations for him [0.5 points].__

# %%
dfSortedCrimeDrama = df[(df['languages'] == '[\'English\']') & (df['genres'].str.contains('Drama' or 'Crime'))]
dfSortedCrimeDrama

# %%
dfSortedCD = dfSortedCrimeDrama.sort_values(by=['rating'], ascending=False)
dfTopCD = dfSortedCD.head(3)
dfTopCD

# %% [markdown]
# ##### __(d) Now, Calvin has watched the movie with the ID 110912. Print the top 3 movies based on the rating attribute, which have the same director as the watched movie with the ID 110912 as recommendations for him. The already watched movie should not be within the recommendations [0.5 points].__

# %%
GetMovie = df[df['id'] == 110912]
GetMovie
## What are the rating attributes? just the rating or also the languages and genres?

# %%
getSortedDirectorGenre = df[df['director'] == 'Quentin Tarantino']
getSortedDirectorGenre

# %%
dfWithoutPF = getSortedDirectorGenre.drop(29)
dfWithoutPF

# %%
dfFinal = dfWithoutPF.sort_values(by=['rating'], ascending=False)
dfFinal

# %%
dfTop3 = dfFinal.head(3)
dfTop3

# %% [markdown]
# ##### __(d) Now, Calvin has watched the movie with the ID 1502397 and we want to recommend movies with a similar plot. Remove all stopwords from the plot attribute and split the content of the plot attribute into terms. Then calculate the term similarity between the plot of the watched movie and all others. Use data pre-processing methods wherever needed. Print the top 3 movies based on the calculated term similarity and the rating of the movie.  [2 points].__

# %%
Movie = df[df['id'] == 1502397]
Movie

# %%
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
all_stopwords = stopwords.words('english') 
stopWord_list = [',', '(', ')', '1', '2', '3', '4', '5', '6', '7', '8', '9', '0', '.']
all_stopwords.extend(stopWord_list)


def getPlotWithoutStopwords(index):
    selectedMovie = df[df['id'] == index]
    Text = selectedMovie['plot'].to_string()
    textWithoutNum = re.sub(r'\d+', '', Text)
    text_tokens = word_tokenize(textWithoutNum)
    tokens_without_sw = [word for word in text_tokens if not word in all_stopwords]
    return tokens_without_sw

referenceTokens = getPlotWithoutStopwords(1502397)
print(referenceTokens)

# %%
distlist = []
for idx in df.index:
    tokens = getPlotWithoutStopwords(int(df.loc[idx, 'id']))
    distlist.append(nltk.edit_distance(''.join(tokens), ''.join(referenceTokens)))
df["LevenDistance"] = distlist
df

# %%
dfSorted = df.sort_values(by=['LevenDistance'], ascending=False)
dfFinal = dfSorted.tail(3)
dfFinal

# %% [markdown]
# ---
#
# ## Exercise 2: Implement Collaborative Filtering Recommenders for the data in the ratings.csv file [6 points].
# ##### __The ratings.csv file contains a dataset extracted from IMDB with ratings for movies from several users. Implement a user-based and an item-based collaborative filtering recommender. Use data pre-processing methods wherever needed. Print the top 3 recommended movies for each user in the dataset for the user-based and the item-based version. Don't recommend any movies the user has already watched.__

# %% [markdown]
# Setup Code

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_csv('ratings.csv')
dm = pd.read_csv('movies.csv')
pd.set_option('max_colwidth', None)
df
# Out:
#            id      user  rating
# 0     2897196  Margaret     3.0
# 1     1329338  Margaret     3.0
# 2     7065882  Margaret     2.0
# 3     1615477  Margaret     5.0
# 4     2316564  Margaret     5.0
# ...       ...       ...     ...
# 3650   559276   Bridget     3.0
# 3651  3295276   Bridget     4.0
# 3652  4138326   Bridget     4.0
# 3653   660187   Bridget     3.0
# 3654  1634540   Bridget     5.0
#
# [3655 rows x 3 columns]

# %% [markdown]
#     We first tried to generate the matrix of simulatiries manually but our code was really inefficient
#     calculation the entire matrix took way too long so we decided to generate the user_similarity matrix
#     using a pivot table and the sklearn library
#
#     https://stackoverflow.com/questions/45387476/cosine-similarity-between-each-row-in-a-dataframe-in-python
#
#     print(generateManual())

# %%
#users = ["not implemented"]
#
#
#def getUsers():
#    users = df["user"].drop_duplicates().tolist()
#    return users
#
#
#def getUserReview(user):
#    # gahn dure und hole alli ratings wo user = user
#    reviews = []
#    for idx in df.index:
#        if df.loc[idx, "user"] == user:
#            reviews.append(df.loc[idx])
#
#    return pd.DataFrame(reviews, columns=["id", "user", "rating"])
#
#
#def getMovieReview(movieID):
#    # gahn dure und hole alli ratings wo Movie = Movie
#    reviews = []
#    for idx in df.index:
#        if df.loc[idx, "id"] == movieID:
#            reviews.append(df.loc[idx])
#    return pd.DataFrame(reviews, columns=["id", "user", "rating"])
#
#
#def findAB(userA, userB):
#    sameReviewedMovies = []
#    reviewlistA = getUserReview(userA)
#    reviewlistB = getUserReview(userB)
#    for idxOfA in reviewlistA.index:
#        for idxOfB in reviewlistB.index:
#            if reviewlistA.loc[idxOfA, "id"] == reviewlistB.loc[idxOfB, "id"]:
#                sameReviewedMovies.append(reviewlistA.loc[idxOfA, "id"])
#    return sameReviewedMovies
#
#
#def similarity(userA, userB):
#    same = findAB(userA, userB)
#    ratingA = []
#    # collet ratings of A
#    for id in same:
#        rating = df[(df["id"] == id) & (df["user"] == userA)]
#        ratingA.append(rating["rating"].tolist()[0])
#
#    ratingB = []
#    # collet ratings of A
#    for id in same:
#        rating = df[(df["id"] == id) & (df["user"] == userB)]
#        ratingB.append(rating["rating"].tolist()[0])
#
#    upperTerm = 0
#    for i in range(len(ratingA)):
#        upperTerm += ratingA[i] * ratingB[i]
#
#    lowerTerm1 = 0
#    allRatingsA = getUserReview(userA)["rating"].tolist()
#    for i in range(len(allRatingsA)):
#        lowerTerm1 += allRatingsA[i] ** 2
#
#    lowerTerm2 = 0
#    allRatingsB = getUserReview(userB)["rating"].tolist()
#    for i in range(len(allRatingsB)):
#        lowerTerm2 += allRatingsB[i] ** 2
#
#    lowerTerm = np.sqrt(lowerTerm1 * lowerTerm2)
#
#    similarity = upperTerm / lowerTerm
#
#    return similarity
#
#
#def applySimilarity(row):
#    for idx in row.index:
#        row.loc[idx] = similarity(row.name, idx)
#    return row
#
#
#def generateManual():
#    ratings = df.pivot_table(index="user", columns="id", values="rating", fill_value=0)
#    user_similarity = pd.DataFrame(1, columns=ratings.index.values, index=ratings.index)
#    user_similarity.apply(applySimilarity, axis=1)
#    return user_similarity
#

# %% [markdown]
# # Real Exercise Code

# %% [markdown]
# ## User Based Recommendations

# %%
users = df["user"].drop_duplicates().tolist()

ratings = df.pivot_table(
    index="user", columns="id", values="rating", fill_value=0
)  # Tabelle generieren mit User und Movie ID und deren Ratings

"""
In diesem Abschnitt werden die Ratings berechnet, dafür haben wir die vordefinierte Funktion cosine_similarity() verwendet von
from sklearn.metrics.pairwise import cosine_similarity
Damit man cosinus_similarity verwenden kann, braucht man eine Matrix mit allen Ratings, die wir der Methode mitgeben.

"""

userSimilarityMatrix = pd.DataFrame(
    cosine_similarity(ratings), columns=ratings.index.values, index=ratings.index
)

movies = dm.set_index("id")  # Movies indexieren

# Get all ratings of movies that the "user" did not saw
def getUnseenRatings(ratings, user):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    all_movies = ratings.columns.values
    unseen_movies = np.setdiff1d(all_movies, seen_movies)
    return ratings.loc[getSimilarUsers(user).index, unseen_movies]


# Multiply rating of unseen movies with simularity score of simlar users according to slide 23 of MLDM_05_RecommenderSystems_mony.pdf
# Then devide the sum by
def getRecommendationsOfRatings(ratings, user):
    unseenRatings = getUnseenRatings(ratings, user)
    sumOfRating = unseenRatings.mul(getSimilarUsers(user), axis=0).sum()
    sumOfUserSimilarity = getSimilarUsers(user).sum()
    return sumOfRating / sumOfUserSimilarity


# Sort all users expet the "user" according the the similary to the "user"
def getSimilarUsers(user):
    return userSimilarityMatrix.loc[user].sort_values(ascending=False).drop(user)


def getUserBasedRecommendationsFor(user):
    # Get all recommendations
    recommendations = getRecommendationsOfRatings(ratings, user)
    # Get the top 3 movies
    recommendations = recommendations.sort_values(ascending=False).head(3)

    return recommendations


for user in users:
    print(
        "The user-based recommendations for "
        + user
        + " are: "
        + str(getUserBasedRecommendationsFor(user))
    )

# %% [markdown]
# ## Item Base Recommendations

# %%
users = df["user"].drop_duplicates().tolist()

ratings = df.pivot_table(
    index="user", columns="id", values="rating", fill_value=0
)  # Tabelle generieren mit User und Movie ID und deren Ratings

"""
In diesem Abschnitt werden die Ratings berechnet, dafür haben wir die vordefinierte Funktion cosine_similarity() verwendet von
from sklearn.metrics.pairwise import cosine_similarity
Damit man cosinus_similarity verwenden kann, braucht man eine Matrix mit allen Ratings, die wir der Methode mitgeben.

"""

userSimilarityMatrix = pd.DataFrame(
    cosine_similarity(ratings), columns=ratings.index.values, index=ratings.index
)

movies = dm.set_index("id")  # Movies indexieren

# Get all ratings of movies that the "user" did not saw
def getUnseenRatings(ratings, user):
    seen_movies = ratings.loc[user].replace(0, np.nan).dropna().index.values
    all_movies = ratings.columns.values
    unseen_movies = np.setdiff1d(all_movies, seen_movies)
    return ratings.loc[getSimilarUsers(user).index, unseen_movies]


# Multiply rating of unseen movies with simularity score of simlar users according to slide 23 of MLDM_05_RecommenderSystems_mony.pdf
# Then devide the sum by
def getRecommendationsOfRatings(ratings, user):
    unseenRatings = getUnseenRatings(ratings, user)
    sumOfRating = unseenRatings.mul(getSimilarUsers(user), axis=0).sum()
    sumOfUserSimilarity = getSimilarUsers(user).sum()
    return sumOfRating / sumOfUserSimilarity


# Sort all users expet the "user" according the the similary to the "user"
def getSimilarUsers(user):
    return userSimilarityMatrix.loc[user].sort_values(ascending=False).drop(user)


def getUserBasedRecommendationsFor(user):
    # Get all recommendations
    recommendations = getRecommendationsOfRatings(ratings, user)
    # Get the top 3 movies
    recommendations = recommendations.sort_values(ascending=False).head(3)

    return recommendations


for user in users:
    print(
        "The item-based recommendations for "
        + user
        + " are: "
        + str(getUserBasedRecommendationsFor(user))
    )
# Out:
# The item-based recommendations for Margaret are: 71562     0.0
# 468569    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Mandy are: 68646       0.0
# John        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Carolyn are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Stephen are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Mario are: 68646       0.0
# John        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Addie are: 68646       0.0
# 71562       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Carl are: 68646       0.0
# 71562       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Reid are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Clara are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Carmen are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Ruth are: 68646     0.0
# 71562     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Daniel are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Robert are: 71562     0.0
# 468569    0.0
# Ralph     0.0
# dtype: float64
# The item-based recommendations for Jacquelyn are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Kendra are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Amanda are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for Jack are: 68646       0.0
# 71562       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Flora are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Sandra are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Richard are: 68646     0.0
# Julian    0.0
# Ralph     0.0
# dtype: float64
# The item-based recommendations for Rita are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Sarah are: Connie     0.0
# Adam       0.0
# Araceli    0.0
# dtype: float64
# The item-based recommendations for Coy are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Gary are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Tracy are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Joshua are: 68646    0.0
# Julie    0.0
# Reid     0.0
# dtype: float64
# The item-based recommendations for Thomas are: 68646       0.0
# Margaret    0.0
# Nathan      0.0
# dtype: float64
# The item-based recommendations for Jerry are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Steven are: Sarah      0.0
# Amy        0.0
# William    0.0
# dtype: float64
# The item-based recommendations for Mark are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for David are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Della are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Maricela are: 68646       0.0
# Margaret    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Barbara are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Julie are: 71562     0.0
# 468569    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Louise are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Ruby are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for John are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for William are: 68646       0.0
# Margaret    0.0
# Nathan      0.0
# dtype: float64
# The item-based recommendations for Matthew are: 68646       0.0
# Maricela    0.0
# Ralph       0.0
# dtype: float64
# The item-based recommendations for Charles are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for Stacy are: 68646       0.0
# Patricia    0.0
# Monica      0.0
# dtype: float64
# The item-based recommendations for Iris are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Millie are: 468569    0.0
# Mario     0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Connie are: Sarah      0.0
# Suzanne    0.0
# Carmen     0.0
# dtype: float64
# The item-based recommendations for Tammie are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Ann are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Jorge are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for Leonard are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for Lenna are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Josephine are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Jeremy are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Sebastian are: 68646       0.0
# Patricia    0.0
# Monica      0.0
# dtype: float64
# The item-based recommendations for Rosalind are: 68646       0.0
# Patricia    0.0
# Monica      0.0
# dtype: float64
# The item-based recommendations for Sam are: 68646     0.0
# John      0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Stacie are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Leigh are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Michael are: Connie     0.0
# Leigh      0.0
# Anthony    0.0
# dtype: float64
# The item-based recommendations for Ana are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Nathan are: 68646       0.0
# Maricela    0.0
# Ralph       0.0
# dtype: float64
# The item-based recommendations for Anthony are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Araceli are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Patricia are: 68646      0.0
# Malcolm    0.0
# Monica     0.0
# dtype: float64
# The item-based recommendations for Verna are: Aaron      0.0
# Allison    0.0
# Max        0.0
# dtype: float64
# The item-based recommendations for Julian are: 68646       0.0
# 71562       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Suzanne are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Stacey are: 68646     0.0
# 71562     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Aaron are: 71562     0.0
# 468569    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Antonio are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Mathew are: Sarah       0.0
# Mandy       0.0
# Kathleen    0.0
# dtype: float64
# The item-based recommendations for Allison are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Willie are: 68646      0.0
# Malcolm    0.0
# Monica     0.0
# dtype: float64
# The item-based recommendations for Adam are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Leslie are: Sarah    0.0
# Bob      0.0
# Ana      0.0
# dtype: float64
# The item-based recommendations for Amy are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Gladys are: Frank       0.0
# Clifford    0.0
# Jeremy      0.0
# dtype: float64
# The item-based recommendations for Kathleen are: 68646       0.0
# 71562       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Carlos are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Ron are: 68646       0.0
# Patricia    0.0
# Monica      0.0
# dtype: float64
# The item-based recommendations for Scott are: 68646      0.0
# Malcolm    0.0
# Monica     0.0
# dtype: float64
# The item-based recommendations for Eric are: 468569    0.0
# Mark      0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Maryann are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Howard are: 68646      0.0
# Richard    0.0
# Ralph      0.0
# dtype: float64
# The item-based recommendations for Brian are: 68646    0.0
# Julie    0.0
# Reid     0.0
# dtype: float64
# The item-based recommendations for Marie are: 68646     0.0
# Julian    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Katharine are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Blake are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Carissa are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Ralph are: Sharon     0.0
# Ron        0.0
# Carolyn    0.0
# dtype: float64
# The item-based recommendations for Max are: 68646      0.0
# Malcolm    0.0
# Nathan     0.0
# dtype: float64
# The item-based recommendations for Clifford are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for George are: Kendra      0.0
# Kathleen    0.0
# Ronny       0.0
# dtype: float64
# The item-based recommendations for Henry are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Irene are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Sharon are: 468569    0.0
# Mario     0.0
# Ralph     0.0
# dtype: float64
# The item-based recommendations for Jessica are: 71562     0.0
# 468569    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for James are: 68646    0.0
# Marie    0.0
# Ralph    0.0
# dtype: float64
# The item-based recommendations for Ronald are: 71562     0.0
# 468569    0.0
# Ralph     0.0
# dtype: float64
# The item-based recommendations for Monica are: 68646     0.0
# Julian    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Craig are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Valorie are: 68646       0.0
# Margaret    0.0
# Nathan      0.0
# dtype: float64
# The item-based recommendations for Bob are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Esteban are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Ronny are: 68646       0.0
# Maricela    0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Frank are: Connie     0.0
# Carolyn    0.0
# Tracy      0.0
# dtype: float64
# The item-based recommendations for Antonia are: 71562     0.0
# 468569    0.0
# Reid      0.0
# dtype: float64
# The item-based recommendations for Carol are: 68646     0.0
# Mandy     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Evelyn are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Sean are: 68646       0.0
# Reid        0.0
# Patricia    0.0
# dtype: float64
# The item-based recommendations for Malcolm are: 68646     0.0
# Ralph     0.0
# Nathan    0.0
# dtype: float64
# The item-based recommendations for Bridget are: 68646       0.0
# Jorge       0.0
# Patricia    0.0
# dtype: float64

# %% [markdown]
# ---
#
# ## Exercise 3: Extend the Collaborative Filtering Recommender [5 points].
#
# You are free to choose which additional task you want to do. Ideas could be:
# - Implement your own UI for the Recommendation System.
# - Create a blogpost on the internet describing your approach and the system (Note: Do not just upload the notebook but create a text with references to the literature and appropriate plots).
# - Test alternative approaches to create recommendations and compare them.
# - **... your own idea ...**
#
# If you solve this task in this notebook, just describe your idea in a few sentences. If you do not solve it in the notebook, please provide a more detailed description and screenshots if appropriate.
#
# This exercise must be presented during the lab session. The task is graded based on innovation, effort, result, ...

# %% [markdown]
# ### Describe your idea here:
#
# .....

# %% [markdown]
# # Ideas
#
# - Optimize approach (might be difficult)
# - Verify Solution by using numbers from slides using fruits and doctors
# - Showing Learing steps about ineffictions (TODO SELIM ASK ABOUT IDEA)
